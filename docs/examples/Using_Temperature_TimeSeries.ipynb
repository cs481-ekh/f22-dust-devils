# %% [markdown]
# # Using Muldoon - Temperature Timeseries

# %% [markdown]
# Here are some examples for how to use some of the functionality of Muldoon.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# for local testing
# import sys 
# sys.path.insert(0,"/root/481-SeniorDesign/f22-dust-devils/muldoon")
# from met_timeseries import TemperatureTimeseries
# from read_data import read_data
# from utils import *

# import numpy as np
# import matplotlib.pyplot as plt

# from numpy.random import normal

# from scipy.stats import median_abs_deviation as mad

# from muldoon.met_timeseries import MetTimeseries, PressureTimeseries, TemperatureTimeseries
# from muldoon.utils import modified_lorentzian, fit_vortex_ps, write_out_plot_data
# from ../muldoon/read_data import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ---
# Using the TemperatureTimeseries Class

# %%
#pds4 option
filename = 'https://pds-atmospheres.nmsu.edu/PDS/data/PDS4/Mars2020/mars2020_meda/data_calibrated_env/sol_0000_0089/sol_0010/WE__0010___________CAL_ATS_________________P01.xml'

#plotting time vs temperarture
plot_Perseverance_ATS_data(filename)
# Out:
# Processing label: https://pds-atmospheres.nmsu.edu/PDS/data/PDS4/Mars2020/mars2020_meda/data_calibrated_env/sol_0000_0089/sol_0010/WE__0010___________CAL_ATS_________________P01.xml
# Found a Header structure: HEADER
# Found a Table_Delimited structure: TABLE
# 0   Header           'HEADER'  PDS DSV 1
# 1   Table_Delimited  'TABLE'   8 fields x 2685 records
# ...
